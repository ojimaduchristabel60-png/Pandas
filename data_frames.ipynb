# %%
import pandas as pd

# %%
excel = pd.read_excel("sample.xls")

# %%
print(excel)

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
names = ["John","mary","Peter","James"]
ages = [20,21,22,19]

# %%
plt.bar(names,ages)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.ylabel('Ages')
# Out:
# Text(0, 0.5, 'Ages')

# %%
plt.pie(ages,labels=names,autopct=)
